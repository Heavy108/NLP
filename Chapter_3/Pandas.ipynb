# %%
import pandas as pd

# %%
df =pd.DataFrame([[1,2,3,],[2,3,5],[3,5,7]] ,columns=['A','B','C'] ,index=['X','Y','Z'])
df.head()
# Out:
#    A  B  C
# X  1  2  3
# Y  2  3  5
# Z  3  5  7

# %%
df.index.to_list()
# Out:
# ['X', 'Y', 'Z']

# %%
df.describe()
# Out:
#          A         B    C
# count  3.0  3.000000  3.0
# mean   2.0  3.333333  5.0
# std    1.0  1.527525  2.0
# min    1.0  2.000000  3.0
# 25%    1.5  2.500000  4.0
# 50%    2.0  3.000000  5.0
# 75%    2.5  4.000000  6.0
# max    3.0  5.000000  7.0

# %%
print(df.shape)
print(df.info())
# Out:
# (3, 3)
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, X to Z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 204.0+ bytes
# None

# %%
df.size
# Out:
# 9
